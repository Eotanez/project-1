# %%
#coded by nicole
#import dependencies
import pandas as pd

# %%
#reference file
file = "Data/owid-covid-data.csv"

#import data into DataFrame
who_data = pd.read_csv(file)
who_data
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 84754      ZWE    Africa     Zimbabwe  2021-04-24      38064.0       19.0
# 84755      ZWE    Africa     Zimbabwe  2021-04-25      38086.0       22.0
# 84756      ZWE    Africa     Zimbabwe  2021-04-26      38102.0       16.0
# 84757      ZWE    Africa     Zimbabwe  2021-04-27      38164.0       62.0
# 84758      ZWE    Africa     Zimbabwe  2021-04-28      38191.0       27.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
#columns
who_data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
death_rate = who_data.loc[:, ["location", "date", "total_deaths_per_million"]]
death_rate
# Out:
#           location        date  total_deaths_per_million
# 0      Afghanistan  2020-02-24                       NaN
# 1      Afghanistan  2020-02-25                       NaN
# 2      Afghanistan  2020-02-26                       NaN
# 3      Afghanistan  2020-02-27                       NaN
# 4      Afghanistan  2020-02-28                       NaN
# ...            ...         ...                       ...
# 84754     Zimbabwe  2021-04-24                   104.690
# 84755     Zimbabwe  2021-04-25                   104.757
# 84756     Zimbabwe  2021-04-26                   104.959
# 84757     Zimbabwe  2021-04-27                   105.296
# 84758     Zimbabwe  2021-04-28                   105.296
#
# [84759 rows x 3 columns]

# %%
reduced_who_data = who_data.loc[:, ["continent", "location", "population", "date", "total_cases", "total_deaths", "new_deaths"]]
reduced_who_data
# Out:
#       continent     location        date  total_cases  new_cases  \
# 0          Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          Asia  Afghanistan  2020-02-28          1.0        0.0
# ...         ...          ...         ...          ...        ...
# 84754    Africa     Zimbabwe  2021-04-24      38064.0       19.0
# 84755    Africa     Zimbabwe  2021-04-25      38086.0       22.0
# 84756    Africa     Zimbabwe  2021-04-26      38102.0       16.0
# 84757    Africa     Zimbabwe  2021-04-27      38164.0       62.0
# 84758    Africa     Zimbabwe  2021-04-28      38191.0       27.0
#
#        total_deaths  new_deaths
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# ...

# %%
#Brazil
#Canada
#China
#Germany
#India
#Japan
#Mexico
#US

# %%
US_death = who_data.loc[who_data["location"] == "United States", :]
US_death["total_deaths_per_million"].max()
# Out:
# 1735.152

# %%
Brazil_death = who_data.loc[who_data["location"] == "Brazil", :]
Brazil_death["total_deaths_per_million"].max()
# Out:
# 1873.2879999999998

# %%
Canada_death = who_data.loc[who_data["location"] == "Canada", :]
Canada_death["total_deaths_per_million"].max()
# Out:
# 638.808

# %%
China_death = who_data.loc[who_data["location"] == "China", :]
China_death["total_deaths_per_million"].max()
# Out:
# 3.366

# %%
reduced_who_data.to_csv("Data/reduced_who_data.csv", index=False, header=True)

# %%
only_US = who_data.loc[who_data["location"] == "United States", :]
only_US["population"]
# Out:
# 80353    331002647.0
# 80354    331002647.0
# 80355    331002647.0
# 80356    331002647.0
# 80357    331002647.0
#             ...
# 80811    331002647.0
# 80812    331002647.0
# 80813    331002647.0
# 80814    331002647.0
# 80815    331002647.0
# Name: population, Length: 463, dtype: float64

# %%
gdp_info = who_data.sort_values("gdp_per_capita", ascending = False)
gdp_info
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 62370      QAT      Asia    Qatar  2021-04-13     191979.0      981.0
# 62212      QAT      Asia    Qatar  2020-11-06     133811.0      192.0
# 62225      QAT      Asia    Qatar  2020-11-19     136649.0      208.0
# 62224      QAT      Asia    Qatar  2020-11-18     136441.0      219.0
# 62223      QAT      Asia    Qatar  2020-11-17     136222.0      194.0
# ...        ...       ...      ...         ...          ...        ...
# 82222      VAT    Europe  Vatican  2021-04-24         27.0        0.0
# 82223      VAT    Europe  Vatican  2021-04-25         27.0        0.0
# 82224      VAT    Europe  Vatican  2021-04-26         27.0        0.0
# 82225      VAT    Europe  Vatican  2021-04-27         27.0        0.0
# 82226      VAT    Europe  Vatican  2021-04-28         27.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...
